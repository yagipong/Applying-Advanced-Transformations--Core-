# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
df_info = pd.read_csv('Data/superhero_info.csv')
df_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df_info[['Hero', 'Publisher']] = df_info['Hero|Publisher'].str.split('|', expand = True)
df_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
df_info = df_info.drop(columns = 'Hero|Publisher')
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
df_info['Measurements'] = df_info['Measurements'].str.replace("'",'"')
df_info['Measurements'] = df_info['Measurements'].apply(json.loads)
df_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
measurements = df_info['Measurements'].apply(pd.Series)

df_info = pd.concat((df_info, measurements), axis = 1)
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# 2          DC Comics  185.0 cm   90.0 kg
# 3      Marvel Comics  203.0 cm  441.0 kg
# 4      Marvel Comics  193.0 cm  122.0 kg

# %%
df_info = df_info.drop(columns = 'Measurements')

# %%
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
df_info['Height'] = df_info['Height'].str.replace(" cm", '')
df_info['Height'] = df_info['Height'].apply(json.loads)
df_info['Height'].head()
# Out:
# 0    203.0
# 1    191.0
# 2    185.0
# 3    203.0
# 4    193.0
# Name: Height, dtype: float64

# %%
df_info['Weight'] = df_info['Weight'].str.replace(" kg", '')
df_info['Weight'] = df_info['Weight'].apply(json.loads)
df_info['Weight'].head()
# Out:
# 0    441.0
# 1     65.0
# 2     90.0
# 3    441.0
# 4    122.0
# Name: Weight, dtype: float64

# %%
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics   203.0   441.0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0
# 2       Abin Sur          DC Comics   185.0    90.0
# 3    Abomination      Marvel Comics   203.0   441.0
# 4  Absorbing Man      Marvel Comics   193.0   122.0

# %%
df_info = df_info[['Hero', 'Publisher', 'Eye color', 'Race', 'Hair color', 'Height', 
         'Skin color', 'Alignment', 'Weight']]
df_info.head()
# Out:
#             Hero          Publisher Eye color               Race Hair color  \
# 0         A-Bomb      Marvel Comics    yellow              Human    No Hair
# 1     Abe Sapien  Dark Horse Comics      blue      Icthyo Sapien    No Hair
# 2       Abin Sur          DC Comics      blue            Ungaran    No Hair
# 3    Abomination      Marvel Comics     green  Human / Radiation    No Hair
# 4  Absorbing Man      Marvel Comics      blue              Human    No Hair
#
#    Height Skin color Alignment  Weight
# 0   203.0    Unknown      good   441.0
# 1   191.0       blue      good    65.0
# 2   185.0        red      good    90.0
# 3   203.0    Unknown       bad   441.0
# 4   193.0    Unknown       bad   122.0

# %%
df_powers = pd.read_csv('Data/superhero_powers.csv')
df_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
powers = df_powers['Powers'].str.split(',', expand = True)
powers.head()
# Out:
#                     0                    1                2               3   \
# 0              Agility       Super Strength          Stamina     Super Speed
# 1  Accelerated Healing           Durability        Longevity  Super Strength
# 2              Agility  Accelerated Healing  Cold Resistance      Durability
# 3   Lantern Power Ring                 None             None            None
# 4  Accelerated Healing         Intelligence   Super Strength         Stamina
#
#                      4                5                6             7   \
# 0                  None             None             None          None
# 1               Stamina       Camouflage  Self-Sustenance          None
# 2  Underwater breathing     Marksmanship   Weapons Master     Longevity
# 3                  None             None             None          None
# 4           Super Speed  Invulnerability        Animation  Super Breath
#
#              8               9   ...    39    40    41    42    43    44  \
# 0          None            None  ...  None  None  None  None  None  None
# 1          None            None  ...  None  None  None  None  None  None
# 2  Intelligence  Super Strength  ...  None  None  None  None  None  None
# 3          None            None  ...  None  None  None  None  None  None
# 4          None            None  ...  None  None  None  None  None  None
#
#      45    46    47    48
# 0  None  None  None  None
# 1  None  None  None  None
# 2  None  None  None  None
# 3  None  None  None  None
# 4  None  None  None  None
#
# [5 rows x 49 columns]

# %%
cols_to_make = powers.dropna()
cols_to_make
# Out:
#           0                    1                      2        3   \
# 563  Agility  Accelerated Healing  Dimensional Awareness  Stealth
#
#                     4       5             6          7             8   \
# 563  Energy Absorption  Flight  Marksmanship  Longevity  Intelligence
#
#                  9   ...          39           40         41             42  \
# 563  Super Strength  ...  Levitation  Time Travel  Illusions  Water Control
#
#                  43                 44            45           46  \
# 563  Omnilingualism  Time Manipulation  Invisibility  Sub-Mariner
#
#                 47               48
# 563  Vision - Heat  Reality Warping
#
# [1 rows x 49 columns]

# %%
for col in cols_to_make:
    df_powers[col] = df_powers['Powers'].str.contains(col)
    
df_powers.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [60], line 2
#       1 for col in cols_to_make:
# ----> 2     df_powers[col] = df_powers['Powers'].str.contains(col)
#       4 df_powers.head()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/strings/accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/strings/accessor.py:1252, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1127 @forbid_nonstring_types(["bytes"])
#    1128 def contains(self, pat, case=True, flags=0, na=None, regex=True):
#    1129     r"""
#    1130     Test if pattern or regex is contained within a string of a Series or Index.
#    1131
#    (...)
#    1250     dtype: bool
#    1251     """
# -> 1252     if regex and re.compile(pat).groups:
#    1253         warnings.warn(
#    1254             "This pattern is interpreted as a regular expression, and has "
#    1255             "match groups. To actually get the groups, use str.extract.",
#    1256             UserWarning,
#    1257             stacklevel=find_stack_level(),
#    1258         )
#    1260     result = self._data.array._str_contains(pat, case, flags, na, regex)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/re.py:303, in _compile(pattern, flags)
#     301     return pattern
#     302 if not sre_compile.isstring(pattern):
# --> 303     raise TypeError("first argument must be string or compiled pattern")
#     304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#
# TypeError: first argument must be string or compiled pattern
